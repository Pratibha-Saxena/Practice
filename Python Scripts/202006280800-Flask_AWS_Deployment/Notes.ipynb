# %% [raw]
# What is deployment ??

# %% [raw]
# Your User should be able to use the application to find out like:
#     RND = 300000
#     MKT = 200000
#
#     Profit = ??

# %% [raw]
# ------------PreRequisites------------
#     flask
#     amazon AWS account
#
# pip install flask

# %% [raw]
# ------------FLASK STRUCTURE------------
# app.py (Contains application flow)
# model.py (Contains code to create ML model)
# model.pkl (Generated by model.py to store the trained model)
# index.html (Contains HTML code for the form)

# %% [raw]
# ------------STEPS------------
# 1. AWS --> EC2 --> Security group --> port 39 --> keypair download
# 2. ssh --> login
# 3. Packages --> install the required pkgs
# 4. Server script --> execute the commands on server (listed below)
# 5. filezilla/winscp --> login
# 6. Transfer code from your local machine to cloud machine
# 7. Start gunicorn app
# 8. Application is deployed: Check on internet

# %% [markdown]
# # Server script --> execute the commands on server

# %% [raw]
# Server script --> execute the commands on server
#
# sudo apt-get update
# sudo apt-get install python3.6
# sudo apt-get install python3-pip
# sudo apt-get install nginx
# sudo apt-get install gunicorn3
# pip3 install flask
# pip3 install pandas
# pip3 install numpy
# pip3 install sklearn
#
# cd /etc/nginx/sites-enabled
# sudo nano proj1
# server{
#
#   listen 39;
#   server_name 3.101.30.13;
#
#   location / {
#     proxy_pass http://127.0.0.1:8000;
#   }
# }
#
# sudo service nginx restart
# gunicorn3 app:app

# %% [raw]
# https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/putty.html
# https://glassonionblog.wordpress.com/2012/01/29/connect-to-an-ec2-instance-with-putty-winscp/
