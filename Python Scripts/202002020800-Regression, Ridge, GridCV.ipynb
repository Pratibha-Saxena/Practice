# %%
import pandas as pd
df_startups = pd.read_csv("C:/Users/Admin/Documents/Datasets/50_Startups (1).csv")
df_iris = pd.read_csv("C:/Users/Admin/Documents/Datasets/iris.csv")

# %%
df_startups.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
df.corr()
# Out:
#               Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Unnamed: 0      1.000000      0.716676    -0.402301      0.882637     0.900027
# Sepal.Length    0.716676      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width    -0.402301     -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length    0.882637      0.871754    -0.428440      1.000000     0.962865
# Petal.Width     0.900027      0.817941    -0.366126      0.962865     1.000000

# %%
from sklearn.model_selection import train_test_split
X = df_startups[["RND", "ADMIN", "MKT"]]
y = df_startups[["PROFIT"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# %% [markdown]
# # MLR

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, y_train)
pred = lm.predict(X_test)
pred
# Out:
# array([[ 74061.52789389],
#        [116335.01208174],
#        [ 96301.75186829],
#        [ 57815.73693357],
#        [134382.77734484],
#        [ 99335.39707978],
#        [ 97159.3839771 ],
#        [100238.76971985],
#        [ 87639.69810774],
#        [112004.50975126]])

# %%
model.score(X_test, y_test)
# Out:
# 0.8732163182444226

# %%
model.intercept_
# Out:
# array([49187.32503909])

# %%
model.coef_
# Out:
# array([[ 0.79690974, -0.03941993,  0.03639162]])

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test, pred))
# Out:
# 5974.555319612919

# %% [markdown]
# # Ridge

# %%
q = 1
tpr = []
for i in range(1, 10000, 1):
    tpr.append(q + 0.1)
    q = q + 0.01
tpr
# Out:
# [1.1,
#  1.11,
#  1.12,
#  1.1300000000000001,
#  1.1400000000000001,
#  1.1500000000000001,
#  1.1600000000000001,
#  1.1700000000000002,
#  1.1800000000000002,
#  1.1900000000000002,
#  1.2000000000000002,
#  1.2100000000000002,
#  1.2200000000000002,
#  1.2300000000000002,
#  1.2400000000000002,
#  1.2500000000000002,
#  1.2600000000000002,
#  1.2700000000000002,
#  1.2800000000000002,
#  1.2900000000000003,
#  1.3000000000000003,
#  1.3100000000000003,
#  1.3200000000000003,
#  1.3300000000000003,
#  1.3400000000000003,
#  1.3500000000000003,
#  1.3600000000000003,
#  1.3700000000000003,
#  1.3800000000000003,
#  1.3900000000000003,
#  1.4000000000000004,
#  1.4100000000000004,
#  1.4200000000000004,
#  1.4300000000000004,
#  1.4400000000000004,
#  1.4500000000000004,
#  1.4600000000000004,
#  1.4700000000000004,
#  1.4800000000000004,
#  1.4900000000000004,
#  1.5000000000000004,
#  1.5100000000000005,
#  1.5200000000000005,
#  1.5300000000000005,
#  1.5400000000000005,
# ...

# %%
from sklearn.linear_model import Ridge
tp = {'alpha': tpr}
rr = Ridge()
from sklearn.model_selection import GridSearchCV
cv = GridSearchCV(rr, tp, scoring="explained_variance", cv=4)
cv.fit(X_train, y_train)
cv.best_params_
# Out:
# {'alpha': 101.08000000001475}

# %%
rr = Ridge(alpha=101.08000000001475)
rr.fit(X_train, y_train)
rr_pred = rr.predict(X_test)
print(mean_absolute_error(y_test, rr_pred))
# Out:
# 5974.555336933106

# %%
tpr
# Out:
# [1.1,
#  1.11,
#  1.12,
#  1.1300000000000001,
#  1.1400000000000001,
#  1.1500000000000001,
#  1.1600000000000001,
#  1.1700000000000002,
#  1.1800000000000002,
#  1.1900000000000002,
#  1.2000000000000002,
#  1.2100000000000002,
#  1.2200000000000002,
#  1.2300000000000002,
#  1.2400000000000002,
#  1.2500000000000002,
#  1.2600000000000002,
#  1.2700000000000002,
#  1.2800000000000002,
#  1.2900000000000003,
#  1.3000000000000003,
#  1.3100000000000003,
#  1.3200000000000003,
#  1.3300000000000003,
#  1.3400000000000003,
#  1.3500000000000003,
#  1.3600000000000003,
#  1.3700000000000003,
#  1.3800000000000003,
#  1.3900000000000003,
#  1.4000000000000004,
#  1.4100000000000004,
#  1.4200000000000004,
#  1.4300000000000004,
#  1.4400000000000004,
#  1.4500000000000004,
#  1.4600000000000004,
#  1.4700000000000004,
#  1.4800000000000004,
#  1.4900000000000004,
#  1.5000000000000004,
#  1.5100000000000005,
#  1.5200000000000005,
#  1.5300000000000005,
#  1.5400000000000005,
# ...

# %% [markdown]
# PPT for regression: https://drive.google.com/open?id=1TtwFqE-yyUz3j1fySKK_N59T9hh_VKby
# EDA ppt : https://drive.google.com/open?id=0B_cfs_THLBmJZi1kM3FHazA3Tzh1WVUwOGhhdTFOVnR4dGpF
# ML overview ppt : https://drive.google.com/open?id=1030YhTsKh66IfbhVnmXrLYEu3zQnVE2d
