# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Admin/Documents/Datasets/Cars93.csv")

# %%
df.head()
df = df.iloc[:, 1:]
df.head()
# Out:
#       Type  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 1  Midsize       29.2   33.9       38.7        18           25
# 2  Compact       25.9   29.1       32.3        20           26
# 3  Midsize       30.8   37.7       44.6        19           26
# 4  Midsize       23.7   30.0       36.2        22           30
# 5  Midsize       14.2   15.7       17.3        22           31
#
#               AirBags DriveTrain Cylinders  EngineSize  ...  Passengers  \
# 1  Driver & Passenger      Front         6         3.2  ...           5
# 2         Driver only      Front         6         2.8  ...           5
# 3  Driver & Passenger      Front         6         2.8  ...           6
# 4         Driver only       Rear         4         3.5  ...           4
# 5         Driver only      Front         4         2.2  ...           6
#
#    Length  Wheelbase Width  Turn.circle  Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
quant_features = []
for i in df.columns:
    if df[i].dtypes != 'object':
        quant_features.append(i)
quant_features
# Out:
# ['Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight']

# %%
quant_feature_first_half = quant_features[:9]
quant_feature_second_half = quant_features[9:]
import seaborn as sb
import matplotlib.pyplot as plt
# plt.figure(figsize=(80,23))
# cnt = 1
for i in quant_feature_first_half:
    for j in quant_feature_second_half:
        if i != j:
#             plt.subplot(27, 3, cnt)
            sb.scatterplot(df[i], df[j])
#             cnt += 1
            plt.show()
# plt.show()
