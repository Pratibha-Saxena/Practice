# %%
import pandas as pd
df = pd.read_csv("C:/Users/Admin/Documents/Datasets/Cars93.csv")
df.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0        25           31                None  ...          5    177
# 1        18           25  Driver & Passenger  ...          5    195
# 2        20           26         Driver only  ...          5    180
# 3        19           26  Driver & Passenger  ...          6    193
# 4        22           30         Driver only  ...          4    186
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %%
df.shape
# Out:
# (93, 28)

# %%
from sklearn.decomposition import PCA
pca = PCA()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_1 = df.apply(le.fit_transform)

# %%
model = pca.fit(df_1)

# %%
principle_components = pd.DataFrame(model.components_)

# %%
principle_components
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.219933  0.074887  0.106471  0.004682 -0.388231 -0.399610 -0.376116
# 1   0.648534  0.213990 -0.070768  0.000678  0.185193  0.183715  0.174558
# 2   0.024515  0.003106  0.981050  0.010124  0.018873  0.003039 -0.013029
# 3   0.086105  0.027529 -0.136604  0.007124 -0.264764 -0.334190 -0.373574
# 4   0.010297  0.011674 -0.025167  0.010783 -0.119965 -0.132806 -0.109869
# 5   0.012913 -0.016428 -0.003082  0.105394 -0.304610 -0.088612  0.098100
# 6   0.013953 -0.004126 -0.029288 -0.053117  0.157247 -0.160121 -0.388040
# 7  -0.016936 -0.002920  0.004736  0.017136  0.536171  0.007557 -0.451686
# 8   0.030878  0.002712  0.004503 -0.035255 -0.319605  0.012451  0.249354
# 9   0.001126  0.015325  0.000180  0.022846 -0.186688 -0.021322  0.147367
# 10  0.000240 -0.000358  0.011913 -0.034302 -0.033751 -0.002036  0.038452
# 11  0.010868  0.008906  0.004741 -0.064137  0.085029 -0.000469 -0.048818
# ...

# %%
m = 0
for evr in list(model.explained_variance_ratio_):
    m = m+1
    print("principle_components", m, "%.2f"%(evr))
# Out:
# principle_components 1 0.49
# principle_components 2 0.25
# principle_components 3 0.13
# principle_components 4 0.06
# principle_components 5 0.03
# principle_components 6 0.01
# principle_components 7 0.01
# principle_components 8 0.01
# principle_components 9 0.00
# principle_components 10 0.00
# principle_components 11 0.00
# principle_components 12 0.00
# principle_components 13 0.00
# principle_components 14 0.00
# principle_components 15 0.00
# principle_components 16 0.00
# principle_components 17 0.00
# principle_components 18 0.00
# principle_components 19 0.00
# principle_components 20 0.00
# principle_components 21 0.00
# principle_components 22 0.00
# principle_components 23 0.00
# principle_components 24 0.00
# principle_components 25 0.00
# principle_components 26 0.00
# principle_components 27 0.00
# principle_components 28 0.00
