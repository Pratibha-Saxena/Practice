# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/Admin/Documents/Datasets/ts.csv", names=["year", "passengers"])
df.head()
# Out:
#       year  passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
plt.plot(df[0:7].year, df[0:7].passengers)
# plt.plot(df.year, df.passengers)
plt.xlabel("Months")
plt.ylabel("Number of Passengers")
plt.show()

# %%
df.describe()
# Out:
#        passengers
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    object
#  1   passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
import seaborn as sb
sb.distplot(df.passengers)
plt.show()

# %%
df.index = df.year
df = df.drop(labels=["year"], axis=1)
df.head()
# Out:
#          passengers
# year
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121

# %%
df.index = pd.to_datetime(df.index, format="%Y-%m")

# %%
df.plot()

# %%
# Components: (Trend, Season, Error/Randomness/Unsystematic, short term fluctuations)
from statsmodels.api import tsa
tsa.seasonal_decompose(df).plot()
plt.show()

# %%
import pandasql as ps
mc_df = pd.read_csv("C:/Users/Admin/Documents/Datasets/mcD-generated_dataset.csv")
mc_df.head()
# Out:
#    12-Jun-2020            Aloo tikki  2
# 0  12-Jun-2020              McVeggie  1
# 1  12-Jun-2020                  Chai  2
# 2  12-Jun-2020              McVeggie  1
# 3  12-Jun-2020                 Fries  2
# 4  12-Jun-2020  American Veg supreme  4
