# %%
import pandas as pd
df = pd.read_csv("C:/Users/Admin/Documents/Datasets/Cars93.csv")
df.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0        25           31                None  ...          5    177
# 1        18           25  Driver & Passenger  ...          5    195
# 2        20           26         Driver only  ...          5    180
# 3        19           26  Driver & Passenger  ...          6    193
# 4        22           30         Driver only  ...          4    186
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %%
import seaborn as sb
import matplotlib.pyplot as plt
for i in df.columns:
    if df[i].dtypes == 'object':
        sb.countplot(df.Type, hue=df[i])
    else:
        sb.boxplot(df.Type, df[i])
    plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
X = df.drop(labels=["Unnamed: 0", "Type", "Manufacturer", "Model", "Make", "Passengers"], axis =1)
y = df.Type
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X = X.apply(le.fit_transform)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion="entropy", random_state=30)
model = dtc.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.6842105263157895

# %% [markdown]
# # Trying to compare with the case using LogisticRegressor Classification

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.7894736842105263

# %% [markdown]
# # Trying Pruning on the Tree with GridSearchCV

# %%
X = df.drop(labels=["Unnamed: 0", "Type", "Manufacturer", "Model", "Make", "Passengers"], axis=1)
y = df.Type
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X = X.apply(le.fit_transform)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)
sb.countplot(y)
plt.show()
sb.countplot(y_train)
plt.show()

from sklearn.model_selection import GridSearchCV
dtc1 = DecisionTreeClassifier()
tp = {"random_state": range(2, 20, 1), "min_samples_leaf": range(2, 20, 1)}
cv = GridSearchCV(dtc1, tp, scoring="accuracy", cv=4)
cv_model = cv.fit(X_train, y_train)
rnd = cv_model.best_params_['random_state']
min_smp_lf = cv_model.best_params_['min_samples_leaf']
print(rnd)
print(min_smp_lf)
cv_model.best_score_
# Out:
# 2
# 6
# 0.8106725146198831

# %%
dtc1 = DecisionTreeClassifier(random_state=rnd, min_samples_leaf=min_smp_lf)
model1= dtc1.fit(X_train, y_train)
pred1 = model1.predict(X_test)
accuracy_score(y_test, pred1)
# Out:
# 0.6842105263157895

# %%
from sklearn.tree import export_graphviz
export_graphviz(dtc1, "C:/Users/Admin/Documents/Python Scripts/202004261800-Tree.dot")

# %%
import pydotplus as pdp
graph = pdp.graph_from_dot_file("C:/Users/Admin/Documents/Python Scripts/202004261800-Tree.dot")

# %%
from IPython.display import Image
Image(graph.create_jpg())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-32-5fe50e705d91> in <module>()
#       1 from IPython.display import Image
# ----> 2 Image(graph.create_jpg())
#
# ~\AppData\Roaming\Python\Python36\site-packages\pydotplus\graphviz.py in <lambda>(f, prog)
#    1795             self.__setattr__(
#    1796                 'create_' + frmt,
# -> 1797                 lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798             )
#    1799             f = self.__dict__['create_' + frmt]
#
# ~\AppData\Roaming\Python\Python36\site-packages\pydotplus\graphviz.py in create(self, prog, format)
#    1958             if self.progs is None:
#    1959                 raise InvocationException(
# -> 1960                     'GraphViz\'s executables not found')
#    1961
#    1962         if prog not in self.progs:
#
# ...
