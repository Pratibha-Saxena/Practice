# %%
import pandas as pd
df = pd.read_csv("C:/Users/Admin/Documents/Datasets/Cars93.csv")
df.drop(labels=["Unnamed: 0"], axis=1, inplace=True)
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8        25
# 1        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2         Audi       90  Compact       25.9   29.1       32.3        20
# 3         Audi      100  Midsize       30.8   37.7       44.6        19
# 4          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0           31                None      Front  ...          5     177
# 1           25  Driver & Passenger      Front  ...          5     195
# 2           26         Driver only      Front  ...          5     180
# 3           26  Driver & Passenger      Front  ...          6     193
# 4           30         Driver only       Rear  ...          4     186
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
df[["Luggage.room"]] = df[["Luggage.room"]].fillna(13.890244)
df[["Rear.seat.room"]] = df[["Rear.seat.room"]].fillna(df[["Rear.seat.room"]].mean())

# %%
import matplotlib.pyplot as plt
import seaborn as sb
cat = []
con = []
for i in df.columns:
    if df[i].dtypes=="object":
        cat.append(i)
        sb.countplot(df[i], hue=df.AirBags)
    else:
        con.append(i)
        sb.boxplot(df.AirBags, df[i])
    plt.show()

# %%
# for SGD  =>  df_1 = df[["Type", "EngineSize", "Horsepower", "Rev.per.mile", "Passengers", "Length", "Wheelbase", "Luggage.room", "Origin"]]
df_1 = df[["Type", "Min.Price", "MPG.city", "DriveTrain", "Cylinders", "EngineSize", "Horsepower", "Rev.per.mile", "Man.trans.avail", "Passengers", "Length", "Wheelbase", "Width", "Luggage.room", "Origin"]]

# %%
cat=[]
con=[]
for i in df_1.columns:
    if df_1[i].dtypes == "object":
        cat.append(i)
    else:
        con.append(i)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
B = pd.DataFrame(ss.fit_transform(df_1[con]), columns=con)
B.columns
# Out:
# Index(['Min.Price', 'MPG.city', 'EngineSize', 'Horsepower', 'Rev.per.mile',
#        'Passengers', 'Length', 'Wheelbase', 'Width', 'Luggage.room'],
#       dtype='object')

# %%
B1 = pd.get_dummies(df_1[cat], drop_first=True)
B1.columns
# Out:
# Index(['Type_Large', 'Type_Midsize', 'Type_Small', 'Type_Sporty', 'Type_Van',
#        'DriveTrain_Front', 'DriveTrain_Rear', 'Cylinders_4', 'Cylinders_5',
#        'Cylinders_6', 'Cylinders_8', 'Cylinders_rotary', 'Man.trans.avail_Yes',
#        'Origin_non-USA'],
#       dtype='object')

# %%
X = B1.join(B)
y = df.AirBags
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
from sklearn.neural_network import MLPClassifier
mlpc = MLPClassifier(random_state=20, solver="adam", hidden_layer_sizes=(10, 10), max_iter=1000)
model = mlpc.fit(X_train, y_train)
pred = model.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred) #0.6842105263157895
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 0.7368421052631579

# %% [markdown]
# # Solution provided in class:

# %%
# remove unnecessary
# Divide data into cat,con
# on con --> SS
# on cat --> one hot


# # In[97]:


# A = pd.read_csv("/users/bajajvbh/Desktop/Vaibhav/Datasets/Cars93.csv")
# A.head(3)


# # In[98]:


# A = A.drop(labels=["Unnamed: 0","Manufacturer","Model","Make"],axis=1)


# # In[42]:


# #Divide cols into cat,con

# def catcon(A):
#    cat = []
#    con = []
#    for i in A.columns:
#        if(A[i].dtypes=="object"):
#            cat.append(i)
#        else:
#            con.append(i)
#    return cat,con


# # In[47]:


# def stan(con_cols_list,df):
#    from sklearn.preprocessing import StandardScaler
#    ss = StandardScaler()
#    B = pd.DataFrame(ss.fit_transform(df[con_cols_list]),columns=con_cols_list)
#    return B


# # In[49]:


# def ohe(cat_cols_list,df):
#    import pandas as pd
#    B1 = pd.get_dummies(df[cat_cols_list])
#    return B1


# # In[51]:


# def preprocessing(df):
#    cat,con=catcon(df)
#    df1 = stan(con,df)
#    df2 = ohe(cat,df)
#    newdf = df1.join(df2)
#    return newdf


# # In[99]:


# B = preprocessing(A)


# # In[100]:


# B


# # In[118]:


# A = pd.read_csv("/users/bajajvbh/Desktop/Vaibhav/Datasets/Cars93.csv")


# # In[115]:


# A.columns


# # In[116]:


# A = A.drop(labels=["Unnamed: 0","Make","Manufacturer","Model","AirBags","Rear.seat.room","Luggage.room"],axis=1)


# # In[117]:


# X = preprocessing(A)


# # In[119]:


# Y = A[["AirBags"]]
# Y.AirBags = Y.AirBags.fillna("Driver only")
# #Y.isna().sum()


# # In[120]:


# from sklearn.model_selection import train_test_split
# xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=30)


# # In[121]:


# from sklearn.neural_network import MLPClassifier
# mlp = MLPClassifier(random_state=30)
# tp = {"hidden_layer_sizes":[(10),(10,20),(10,10,10),(20,20,20),(10,100,50),(10,100,120,40)],"solver":["sgd","adam"]}
# from sklearn.model_selection import GridSearchCV
# cv = GridSearchCV(mlp,tp,scoring="accuracy",cv=4)
# cvmodel = cv.fit(xtrain,ytrain)
# cvmodel.best_params_


# # In[88]:


# A.isna().sum()


# # In[92]:


# A.AirBags.fillna("Driver only")


# # In[95]:


# A.AirBags.value_counts()


# # In[96]:


# A.isna().sum()


# # In[129]:


# mlp = MLPClassifier(random_state=30,hidden_layer_sizes=(20,20,20),solver="adam",max_iter=410)
# model = mlp.fit(xtrain,ytrain)
# pred = model.predict(xtest)
# from sklearn.metrics import accuracy_score
