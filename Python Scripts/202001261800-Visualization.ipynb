# %%
import pandas as pd
df = pd.read_csv("C:/Users/Admin/Documents/Datasets/Cars93.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0 Manufacturer       Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura     Integra    Small       12.9   15.9       18.8
# 1           2        Acura      Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi          90  Compact       25.9   29.1       32.3
# 3           4         Audi         100  Midsize       30.8   37.7       44.6
# 4           5          BMW        535i  Midsize       23.7   30.0       36.2
# 5           6        Buick     Century  Midsize       14.2   15.7       17.3
# 6           7        Buick     LeSabre    Large       19.9   20.8       21.7
# 7           8        Buick  Roadmaster    Large       22.6   23.7       24.9
# 8           9        Buick     Riviera  Midsize       26.3   26.3       26.3
# 9          10     Cadillac     DeVille    Large       33.0   34.7       36.3
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# ...

# %%
cat = []
con = []
df.columns
# Out:
# Index(['Unnamed: 0', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
# Unnamed: 0            93 non-null int64
# Manufacturer          93 non-null object
# Model                 93 non-null object
# Type                  93 non-null object
# Min.Price             93 non-null float64
# Price                 93 non-null float64
# Max.Price             93 non-null float64
# MPG.city              93 non-null int64
# MPG.highway           93 non-null int64
# AirBags               93 non-null object
# DriveTrain            93 non-null object
# Cylinders             93 non-null object
# EngineSize            93 non-null float64
# Horsepower            93 non-null int64
# RPM                   93 non-null int64
# Rev.per.mile          93 non-null int64
# Man.trans.avail       93 non-null object
# Fuel.tank.capacity    93 non-null float64
# Passengers            93 non-null int64
# Length                93 non-null int64
# ...

# %%
df['AirBags'].dtypes
df['Min.Price'].dtypes
# Out:
# dtype('float64')

# %%
for i in df.columns:
    if df[i].dtypes == 'object':
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin',
#  'Make']

# %%
con
# Out:
# ['Unnamed: 0',
#  'Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight']

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
sb.countplot(df.AirBags)

# %%
df['AirBags'].value_counts().plot(kind='barh')

# %%
df['Manufacturer'].value_counts().plot(kind='bar')

# %%
df.Manufacturer.value_counts().plot(kind='barh')

# %%
df.Manufacturer.value_counts().plot(kind='pie')
# plt.figure(figsize=(7, 7))

# %%
q = df.AirBags.value_counts()

# %%
q
# Out:
# Driver only           43
# None                  34
# Driver & Passenger    16
# Name: AirBags, dtype: int64

# %%
m = []
for i in q:
    m.append(i)

# %%
m
# Out:
# [43, 34, 16]

# %%
m1 = list(df.AirBags.unique())
m1
# Out:
# ['None', 'Driver & Passenger', 'Driver only']

# %%
m1 = m1[0:3] # in case NaN gets included in unique()'s output, we need to remove it
m1
# Out:
# ['None', 'Driver & Passenger', 'Driver only']

# %%
# plt.barh(m1, m)
plt.barh(df.AirBags.unique(), df.AirBags.value_counts())
# Out:
# <Container object of 3 artists>

# %%
df['Min.Price'].plot(kind='hist')

# %%
sb.distplot(df['Min.Price'])

# %%
for i in cat:
    sb.countplot(df[i])
    plt.show()

# %%
for i in cat:
    df[i].value_counts().plot(kind='barh')
    plt.show()

# %%
for i in con:
    sb.distplot(df[i])
    plt.show()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# C:\Users\Admin\Anaconda3\lib\site-packages\numpy\core\_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-81390de30ba6> in <module>()
#       1 for i in con:
# ----> 2     sb.distplot(df[i])
#       3     plt.show()
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
# ...

# %%
for i in con:
    df[i].plot(kind='hist')
    plt.show()

# %%
for i in df.columns:
    if df[i].dtypes == 'object':
        sb.countplot(df[i])
    else:
        sb.distplot(df[i])
    plt.show()

# %%
df.describe()

# %%
df_try = pd.read_csv("C:/Users/Admin/Downloads/hitters.csv")

# %%
df_try.head()

# %%
df_try.info()

# %%
for i in df_try.columns:
    if df_try[i].dtypes == 'object':
        sb.countplot(df_try[i])
    else:
        sb.distplot(df_try[i])
    plt.show()

# %%
for i in df_try.columns:
    if df_try[i].dtypes=='object':
        df_try[i].value_counts().plot(kind='barh')
    else:
        df_try[i].value_counts().plot(kind='hist')
    plt.show()

# %%
df_try['Unnamed: 0'].value_counts().shape

# %%
plt.scatter(df['Min.Price'], df['MPG.highway'], c='red')
plt.xlabel("Min Price")
plt.ylabel("Highway Mileage")
plt.title("Min Price vs Highway Mileage")
plt.xticks(range(5, 50, 5))
plt.yticks(range(15, 54, 3))

# %%
sb.scatterplot(df['Min.Price'], df['MPG.highway'])
